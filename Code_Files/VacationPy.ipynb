# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 0        0              vorgashor  67.5833   63.9500    -12.82        89
# 1        1  coahuayana de hidalgo  18.7000 -103.6583     27.95        38
# 2        2                  upata   8.0086  -62.3989     34.02        38
# 3        3              adamstown -25.0660 -130.1015     26.16        83
# 4        4    san luis de la loma  17.2706 -100.8939     28.48        50
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       11.18      RU  1710692579
# 1          90        1.27      MX  1710692579
# 2          89        4.30      VE  1710692579
# 3          39        4.50      PN  1710692579
# 4          53        1.76      MX  1710692580

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
City_Data_Map = city_data_df.hvplot.points(
    'Lng',                         
    'Lat',                              
    geo = True,                            
    tiles = 'OSM', 
    color = 'City', 
    size = 'Humidity', 
    frame_height = 500, 
    frame_width = 700)

# Display the map
City_Data_Map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria
# I want to find cities where the max temperature is between 20 and 25 degrees Celsius, the Cloudiness is less than 50 
    # and where wind speeds are less than 5 m/s
narrow_city_df = city_data_df[(city_data_df['Max Temp'] > 20) & 
                              (city_data_df['Max Temp'] < 25) &
                              (city_data_df['Cloudiness'] < 50) & 
                              (city_data_df['Wind Speed'] <= 5)]

# Drop any rows with null values
narrow_city_df = narrow_city_df.dropna(axis = 0, how = 'any')

# Display sample data
narrow_city_df
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 6          6              tura  25.5198   90.2201     21.73        21
# 10        10          naberera  -4.2000   36.9333     21.07        77
# 20        20        san isidro -12.1167  -77.0500     24.77        69
# 22        22             ginir   7.1333   40.7000     21.23        30
# 50        50            musoma  -1.5000   33.8000     24.86        73
# 59        59          balcarce -37.8462  -58.2552     23.23        58
# 74        74           abepura  -2.6333  140.5833     24.45        94
# 107      107         byron bay -28.6500  153.6167     20.39        86
# 109      109    cabo san lucas  22.8909 -109.9124     22.01        69
# 112      112         muang xay  20.7000  101.9833     23.34        39
# 126      126               diu  20.7141   70.9822     24.39        66
# 135      135       west island -12.1568   96.8225     24.99        83
# 149      149      san patricio  28.0170  -97.5169     23.05        74
# 153      153            cuamba -14.8031   36.5372     22.66        89
# 170      170       broken hill -31.9500  141.4333     21.02        66
# 200      200            ormara  25.2088   64.6357     24.38        61
# 215      215        ceerigaabo  10.6162   47.3680     21.48        30
# 227      227       as suwayrah  32.9256   44.7758     22.23        22
# 233      233  flying fish cove -10.4217  105.6791     24.82        88
# 241      241          conduaga   8.8620  117.4893     24.82        81
# 242      242         castillos -34.1667  -53.8333     23.52        50
# 302      302              douz  33.4663    9.0203     24.65        23
# 306      306       kailua-kona  19.6406 -155.9956     21.95        82
# 332      332        quang ngai  15.1167  108.8000     22.34        95
# 374      374          as sanad  34.4628    9.2640     23.14        23
# 390      390         escuinapa  22.8500 -105.8000     24.16        62
# 424      424            masaka  -0.3338   31.7341     23.10        62
# 437      437            bedele   8.4560   36.3530     22.38        32
# 451      451      east ballina -28.8667  153.5833     20.44        86
# 490      490            bantay  17.5847  120.3892     24.43        76
# 497      497              suva -18.1416  178.4415     23.71        94
# 507      507           pokaran  26.9167   71.9167     23.49        10
# 522      522          pasuquin  18.3328  120.6177     23.94        79
# 529      529           emerald -23.5333  148.1667     21.86        83
# 560      560     debre mark'os  10.3500   37.7333     20.95        27
# 562      562            noumea -22.2763  166.4572     23.99        85
# 573      573             metro  -5.1131  105.3067     24.33        90
#
#      Cloudiness  Wind Speed Country        Date
# 6             0        1.42      IN  1710692580
# 10           42        3.16      TZ  1710692581
# 20            0        3.09      PE  1710692508
# 22            5        3.08      ET  1710692585
# 50            7        4.24      TZ  1710692592
# 59            0        2.24      AR  1710692594
# 74           40        1.03      ID  1710692598
# 107          42        2.59      AU  1710692606
# 109           0        1.54      MX  1710691873
# 112           4        1.02      LA  1710692607
# 126           1        3.98      IN  1710692611
# 135          23        0.51      CC  1710692613
# 149          27        3.67      US  1710692616
# 153          25        1.13      MZ  1710692617
# 170          45        4.01      AU  1710692621
# 200           4        3.60      PK  1710692751
# 215           1        4.48      SO  1710692754
# 227          27        4.73      IQ  1710692757
# 233          40        3.09      CX  1710692576
# 241          11        1.19      PH  1710692760
# 242           0        4.01      UY  1710692761
# 302           5        2.36      TN  1710692777
# 306           0        2.06      US  1710692778
# 332           0        1.95      VN  1710692785
# 374          29        2.08      TN  1710692795
# 390          12        1.14      MX  1710692799
# 424           0        3.90      UG  1710692807
# 437          33        1.36      ET  1710692811
# 451          41        2.85      AU  1710692814
# 490           2        1.00      PH  1710692823
# 497          40        0.00      FJ  1710692825
# 507           2        2.83      IN  1710692827
# 522           4        3.59      PH  1710692831
# 529          28        4.60      AU  1710692833
# 560          36        2.65      ET  1710692840
# 562          46        4.59      NC  1710692841
# 573          45        1.28      ID  1710692843

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrow_city_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 6                tura      IN  25.5198   90.2201        21
# 10           naberera      TZ  -4.2000   36.9333        77
# 20         san isidro      PE -12.1167  -77.0500        69
# 22              ginir      ET   7.1333   40.7000        30
# 50             musoma      TZ  -1.5000   33.8000        73
# 59           balcarce      AR -37.8462  -58.2552        58
# 74            abepura      ID  -2.6333  140.5833        94
# 107         byron bay      AU -28.6500  153.6167        86
# 109    cabo san lucas      MX  22.8909 -109.9124        69
# 112         muang xay      LA  20.7000  101.9833        39
# 126               diu      IN  20.7141   70.9822        66
# 135       west island      CC -12.1568   96.8225        83
# 149      san patricio      US  28.0170  -97.5169        74
# 153            cuamba      MZ -14.8031   36.5372        89
# 170       broken hill      AU -31.9500  141.4333        66
# 200            ormara      PK  25.2088   64.6357        61
# 215        ceerigaabo      SO  10.6162   47.3680        30
# 227       as suwayrah      IQ  32.9256   44.7758        22
# 233  flying fish cove      CX -10.4217  105.6791        88
# 241          conduaga      PH   8.8620  117.4893        81
# 242         castillos      UY -34.1667  -53.8333        50
# 302              douz      TN  33.4663    9.0203        23
# 306       kailua-kona      US  19.6406 -155.9956        82
# 332        quang ngai      VN  15.1167  108.8000        95
# 374          as sanad      TN  34.4628    9.2640        23
# 390         escuinapa      MX  22.8500 -105.8000        62
# 424            masaka      UG  -0.3338   31.7341        62
# 437            bedele      ET   8.4560   36.3530        32
# 451      east ballina      AU -28.8667  153.5833        86
# 490            bantay      PH  17.5847  120.3892        76
# 497              suva      FJ -18.1416  178.4415        94
# 507           pokaran      IN  26.9167   71.9167        10
# 522          pasuquin      PH  18.3328  120.6177        79
# 529           emerald      AU -23.5333  148.1667        83
# 560     debre mark'os      ET  10.3500   37.7333        27
# 562            noumea      NC -22.2763  166.4572        85
# 573             metro      ID  -5.1131  105.3067        90

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
hotel_df.loc[6, 'Lat']
# Out:
# 25.5198

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": 'accommodation.hotel',
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tura - nearest hotel: Hotel Polo Orchid
# naberera - nearest hotel: No hotel found
# san isidro - nearest hotel: Soul Mate
# ginir - nearest hotel: No hotel found
# musoma - nearest hotel: New Peninsula Hotel
# balcarce - nearest hotel: Superior 646 Hotel Balcarce
# abepura - nearest hotel: Yoyo
# byron bay - nearest hotel: Lord Byron Resort
# cabo san lucas - nearest hotel: Comfort Rooms
# muang xay - nearest hotel: ໂຮງແຮມງາມລາວ
# diu - nearest hotel: Hotel Ankur
# west island - nearest hotel: Cocos Village Bungalows
# san patricio - nearest hotel: No hotel found
# cuamba - nearest hotel: Pensao Cariaco
# broken hill - nearest hotel: Ibis Styles
# ormara - nearest hotel: No hotel found
# ceerigaabo - nearest hotel: Sanaag Hotel
# as suwayrah - nearest hotel: No hotel found
# flying fish cove - nearest hotel: Christmas Island Lodge
# conduaga - nearest hotel: No hotel found
# castillos - nearest hotel: A mi gente
# douz - nearest hotel: Louage station Douz
# kailua-kona - nearest hotel: Kona Seaside Hotel
# quang ngai - nearest hotel: Ngoc Anh
# as sanad - nearest hotel: No hotel found
# escuinapa - nearest hotel: Hotel Iq
# masaka - nearest hotel: Golf Lane Hotel
# bedele - nearest hotel: No hotel found
# east ballina - nearest hotel: Ballina Beach Resort
# bantay - nearest hotel: Henady Inn
# suva - nearest hotel: Extension 68
# pokaran - nearest hotel: Pokaran Desert Resort
# pasuquin - nearest hotel: Villa del Marj
# emerald - nearest hotel: Emerald Central Hotel
# debre mark'os - nearest hotel: መልካም ፔንሲዮን
# noumea - nearest hotel: Hotel Gondwana
# metro - nearest hotel: Hotel Nuban
#                  City Country      Lat       Lng  Humidity  \
# 6                tura      IN  25.5198   90.2201        21
# 10           naberera      TZ  -4.2000   36.9333        77
# 20         san isidro      PE -12.1167  -77.0500        69
# 22              ginir      ET   7.1333   40.7000        30
# 50             musoma      TZ  -1.5000   33.8000        73
# 59           balcarce      AR -37.8462  -58.2552        58
# 74            abepura      ID  -2.6333  140.5833        94
# 107         byron bay      AU -28.6500  153.6167        86
# 109    cabo san lucas      MX  22.8909 -109.9124        69
# 112         muang xay      LA  20.7000  101.9833        39
# 126               diu      IN  20.7141   70.9822        66
# 135       west island      CC -12.1568   96.8225        83
# 149      san patricio      US  28.0170  -97.5169        74
# 153            cuamba      MZ -14.8031   36.5372        89
# 170       broken hill      AU -31.9500  141.4333        66
# 200            ormara      PK  25.2088   64.6357        61
# 215        ceerigaabo      SO  10.6162   47.3680        30
# 227       as suwayrah      IQ  32.9256   44.7758        22
# 233  flying fish cove      CX -10.4217  105.6791        88
# 241          conduaga      PH   8.8620  117.4893        81
# 242         castillos      UY -34.1667  -53.8333        50
# 302              douz      TN  33.4663    9.0203        23
# 306       kailua-kona      US  19.6406 -155.9956        82
# 332        quang ngai      VN  15.1167  108.8000        95
# 374          as sanad      TN  34.4628    9.2640        23
# 390         escuinapa      MX  22.8500 -105.8000        62
# 424            masaka      UG  -0.3338   31.7341        62
# 437            bedele      ET   8.4560   36.3530        32
# 451      east ballina      AU -28.8667  153.5833        86
# 490            bantay      PH  17.5847  120.3892        76
# 497              suva      FJ -18.1416  178.4415        94
# 507           pokaran      IN  26.9167   71.9167        10
# 522          pasuquin      PH  18.3328  120.6177        79
# 529           emerald      AU -23.5333  148.1667        83
# 560     debre mark'os      ET  10.3500   37.7333        27
# 562            noumea      NC -22.2763  166.4572        85
# 573             metro      ID  -5.1131  105.3067        90
#
#                       Hotel Name
# 6              Hotel Polo Orchid
# 10                No hotel found
# 20                     Soul Mate
# 22                No hotel found
# 50           New Peninsula Hotel
# 59   Superior 646 Hotel Balcarce
# 74                          Yoyo
# 107            Lord Byron Resort
# 109                Comfort Rooms
# 112                 ໂຮງແຮມງາມລາວ
# 126                  Hotel Ankur
# 135      Cocos Village Bungalows
# 149               No hotel found
# 153               Pensao Cariaco
# 170                  Ibis Styles
# 200               No hotel found
# 215                 Sanaag Hotel
# 227               No hotel found
# 233       Christmas Island Lodge
# 241               No hotel found
# 242                   A mi gente
# 302          Louage station Douz
# 306           Kona Seaside Hotel
# 332                     Ngoc Anh
# 374               No hotel found
# 390                     Hotel Iq
# 424              Golf Lane Hotel
# 437               No hotel found
# 451         Ballina Beach Resort
# 490                   Henady Inn
# 497                 Extension 68
# 507        Pokaran Desert Resort
# 522               Villa del Marj
# 529        Emerald Central Hotel
# 560                   መልካም ፔንሲዮን
# 562               Hotel Gondwana
# 573                  Hotel Nuban

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
Hotel_Data_Map = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = "OSM",
    frame_height = 500, 
    frame_width = 700,
    color = 'City',
    size = 'Humidity',
    hover_cols = ['Hotel Name', 'Country']
)
    

# Display the map
Hotel_Data_Map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
